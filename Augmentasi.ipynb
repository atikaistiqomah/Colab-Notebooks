# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
import os, re, glob, cv2, numpy as np
import tensorflow as tf

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

datagen = ImageDataGenerator(
    horizontal_flip=True)

# %%
i=0
for batch in datagen.flow_from_directory(directory='/content/gdrive/My Drive/Dataset_Aug/kupu_batik_cap',
                                         batch_size=256,
                                         target_size=(224,224),
                                         color_mode="rgb",
                                         save_to_dir='/content/gdrive/My Drive/Augmentasi/kupu_kupu/flip/kupu_batik_cap',
                                         save_prefix='aug',
                                         save_format='JPG') :
  i+=1
  if i > 0:
    break
# Out:
# Found 100 images belonging to 1 classes.

# %%
i=0
for batch in datagen.flow_from_directory(directory='/content/gdrive/My Drive/Dataset_Aug/kupu_hijau_biru',
                                         batch_size=256,
                                         target_size=(224,224),
                                         color_mode="rgb",
                                         save_to_dir='/content/gdrive/My Drive/Augmentasi/kupu_kupu/flip/kupu_hijau_biru',
                                         save_prefix='aug',
                                         save_format='JPG') :
  i+=1
  if i > 0:
    break
# Out:
# Found 100 images belonging to 1 classes.

# %%
i=0
for batch in datagen.flow_from_directory(directory='/content/gdrive/My Drive/Dataset_Aug/kupu_raja_limau',
                                         batch_size=256,
                                         target_size=(224,224),
                                         color_mode="rgb",
                                         save_to_dir='/content/gdrive/My Drive/Augmentasi/kupu_kupu/flip/kupu_raja_limau',
                                         save_prefix='aug',
                                         save_format='JPG') :
  i+=1
  if i > 0:
    break
# Out:
# Found 100 images belonging to 1 classes.

# %%
i=0
for batch in datagen.flow_from_directory(directory='/content/gdrive/My Drive/Dataset_Aug/kupu_jarak',
                                         batch_size=256,
                                         target_size=(224,224),
                                         color_mode="rgb",
                                         save_to_dir='/content/gdrive/My Drive/Augmentasi/kupu_kupu/flip/kupu_jarak',
                                         save_prefix='aug',
                                         save_format='JPG') :
  i+=1
  if i > 0:
    break
# Out:
# Found 100 images belonging to 1 classes.

# %%
i=0
for batch in datagen.flow_from_directory(directory='/content/gdrive/My Drive/Dataset_Aug/kupu_jojo',
                                         batch_size=256,
                                         target_size=(224,224),
                                         color_mode="rgb",
                                         save_to_dir='/content/gdrive/My Drive/Augmentasi/kupu_kupu/flip/kupu_jojo',
                                         save_prefix='aug',
                                         save_format='JPG') :
  i+=1
  if i > 0:
    break
# Out:
# Found 100 images belonging to 1 classes.

# %%
i=0
for batch in datagen.flow_from_directory(directory='/content/gdrive/My Drive/Dataset_Aug/kupu_pantat_merah',
                                         batch_size=256,
                                         target_size=(224,224),
                                         color_mode="rgb",
                                         save_to_dir='/content/gdrive/My Drive/Augmentasi/kupu_kupu/flip/kupu_pantat_merah',
                                         save_prefix='aug',
                                         save_format='JPG') :
  i+=1
  if i > 0:
    break
# Out:
# Found 100 images belonging to 1 classes.

# %%
i=0
for batch in datagen.flow_from_directory(directory='/content/gdrive/My Drive/Dataset_Aug/kupu_raja_helena',
                                         batch_size=256,
                                         target_size=(224,224),
                                         color_mode="rgb",
                                         save_to_dir='/content/gdrive/My Drive/Augmentasi/kupu_kupu/flip/kupu_raja_helena',
                                         save_prefix='aug',
                                         save_format='JPG') :
  i+=1
  if i > 0:
    break
# Out:
# Found 100 images belonging to 1 classes.

# %%
i=0
for batch in datagen.flow_from_directory(directory='/content/gdrive/My Drive/Dataset_Aug/kupu_harimau_kuning_hijau',
                                         batch_size=256,
                                         target_size=(224,224),
                                         color_mode="rgb",
                                         save_to_dir='/content/gdrive/My Drive/Augmentasi/kupu_kupu/flip/kupu_harimau_kuning_hijau',
                                         save_prefix='aug',
                                         save_format='JPG') :
  i+=1
  if i > 0:
    break
# Out:
# Found 100 images belonging to 1 classes.

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

datagen = ImageDataGenerator(
     vertical_flip=True)

# %%
i=0
for batch in datagen.flow_from_directory(directory='/content/gdrive/My Drive/Dataset_Aug/kupu_batik_cap',
                                         batch_size=256,
                                         target_size=(224,224),
                                         color_mode="rgb",
                                         save_to_dir='/content/gdrive/My Drive/Augmentasi/kupu_kupu/flip/kupu_batik_cap',
                                         save_prefix='aug',
                                         save_format='JPG') :
  i+=1
  if i > 0:
    break
# Out:
# Found 100 images belonging to 1 classes.

# %%
i=0
for batch in datagen.flow_from_directory(directory='/content/gdrive/My Drive/Dataset_Aug/kupu_hijau_biru',
                                         batch_size=256,
                                         target_size=(224,224),
                                         color_mode="rgb",
                                         save_to_dir='/content/gdrive/My Drive/Augmentasi/kupu_kupu/flip/kupu_hijau_biru',
                                         save_prefix='aug',
                                         save_format='JPG') :
  i+=1
  if i > 0:
    break
# Out:
# Found 100 images belonging to 1 classes.

# %%
i=0
for batch in datagen.flow_from_directory(directory='/content/gdrive/My Drive/Dataset_Aug/kupu_raja_limau',
                                         batch_size=256,
                                         target_size=(224,224),
                                         color_mode="rgb",
                                         save_to_dir='/content/gdrive/My Drive/Augmentasi/kupu_kupu/flip/kupu_raja_limau',
                                         save_prefix='aug',
                                         save_format='JPG') :
  i+=1
  if i > 0:
    break
# Out:
# Found 100 images belonging to 1 classes.

# %%
i=0
for batch in datagen.flow_from_directory(directory='/content/gdrive/My Drive/Dataset_Aug/kupu_jarak',
                                         batch_size=256,
                                         target_size=(224,224),
                                         color_mode="rgb",
                                         save_to_dir='/content/gdrive/My Drive/Augmentasi/kupu_kupu/flip/kupu_jarak',
                                         save_prefix='aug',
                                         save_format='JPG') :
  i+=1
  if i > 0:
    break
# Out:
# Found 100 images belonging to 1 classes.

# %%
i=0
for batch in datagen.flow_from_directory(directory='/content/gdrive/My Drive/Dataset_Aug/kupu_jojo',
                                         batch_size=256,
                                         target_size=(224,224),
                                         color_mode="rgb",
                                         save_to_dir='/content/gdrive/My Drive/Augmentasi/kupu_kupu/flip/kupu_jojo',
                                         save_prefix='aug',
                                         save_format='JPG') :
  i+=1
  if i > 0:
    break
# Out:
# Found 100 images belonging to 1 classes.

# %%
i=0
for batch in datagen.flow_from_directory(directory='/content/gdrive/My Drive/Dataset_Aug/kupu_pantat_merah',
                                         batch_size=256,
                                         target_size=(224,224),
                                         color_mode="rgb",
                                         save_to_dir='/content/gdrive/My Drive/Augmentasi/kupu_kupu/flip/kupu_pantat_merah',
                                         save_prefix='aug',
                                         save_format='JPG') :
  i+=1
  if i > 0:
    break
# Out:
# Found 100 images belonging to 1 classes.

# %%
i=0
for batch in datagen.flow_from_directory(directory='/content/gdrive/My Drive/Dataset_Aug/kupu_raja_helena',
                                         batch_size=256,
                                         target_size=(224,224),
                                         color_mode="rgb",
                                         save_to_dir='/content/gdrive/My Drive/Augmentasi/kupu_kupu/flip/kupu_raja_helena',
                                         save_prefix='aug',
                                         save_format='JPG') :
  i+=1
  if i > 0:
    break
# Out:
# Found 100 images belonging to 1 classes.

# %%
i=0
for batch in datagen.flow_from_directory(directory='/content/gdrive/My Drive/Dataset_Aug/kupu_harimau_kuning_hijau',
                                         batch_size=256,
                                         target_size=(224,224),
                                         color_mode="rgb",
                                         save_to_dir='/content/gdrive/My Drive/Augmentasi/kupu_kupu/flip/kupu_harimau_kuning_hijau',
                                         save_prefix='aug',
                                         save_format='JPG') :
  i+=1
  if i > 0:
    break
# Out:
# Found 100 images belonging to 1 classes.

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

datagen = ImageDataGenerator(brightness_range=[0.9,1.0])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-15-8a7628508cac> in <module>()
#       1 from tensorflow.keras.preprocessing.image import ImageDataGenerator
#       2
# ----> 3 datagen = ImageDataGenerator(scales=0.75)
#
# TypeError: __init__() got an unexpected keyword argument 'scales'

# %%
i=0
for batch in datagen.flow_from_directory(directory='/content/gdrive/My Drive/Dataset_Aug/kupu_batik_cap',
                                         batch_size=256,
                                         target_size=(224,224),
                                         color_mode="rgb",
                                         save_to_dir='/content/gdrive/My Drive/Augmentasi/kupu_kupu/bright/kupu_batik_cap',
                                         save_prefix='aug',
                                         save_format='JPG') :
  i+=1
  if i > 0:
    break
# Out:
# Found 100 images belonging to 1 classes.

# %%
i=0
for batch in datagen.flow_from_directory(directory='/content/gdrive/My Drive/Dataset_Aug/kupu_harimau_kuning_hijau',
                                         batch_size=256,
                                         target_size=(224,224),
                                         color_mode="rgb",
                                         save_to_dir='/content/gdrive/My Drive/Augmentasi/kupu_kupu/bright/kupu_batik_cap',
                                         save_prefix='aug',
                                         save_format='JPG') :
  i+=1
  if i > 1:
    break
